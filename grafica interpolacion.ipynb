# %%
from pylab import*
from matplotlib import*

# %%
poli = numpy.poly1d([0,0.06,-0.35,0.08,0.97])
print(poli)
# Out:
#       3        2
# 0.06 x - 0.35 x + 0.08 x + 0.97

# %%
x=linspace(1,3,500)
plot(x,poli(x))
