# %%
from pylab import*
from matplotlib import*

# %%
def f(x):
    return (x**2)-exp(x)
a=-1
b=1
x=linspace(-1,1,500)
plot(x,g(x))

# %%
for i in range(100):
    if f(a)>0 and f(b)<0:
        p=((a+b)/2)
    if f(p)>0: 
        a=p 
        
    else: b=p

# %%
t=f(p)
print (t)
print (p)
# Out:
# 0.0
# -0.7034674224983917
